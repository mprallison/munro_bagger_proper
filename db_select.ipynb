# %%
import sys
import os
import sqlite3
import pandas as pd

db_file = "database.db"

sys.path.append(os.path.abspath("routes"))

from munro_data import *

# %%
conn = sqlite3.connect(db_file)
cur = conn.cursor()

# %%
#munro_df = pd.read_sql_query("SELECT * FROM munros", conn)
#munro_df.head()

# %%
user_df = pd.read_sql_query("SELECT * FROM bags where user_id = 'u001'", conn)
user_df
# Out:
#    user_id munro_id        date distance  \
# 0     u001     m056    9/7/2019     None
# 1     u001     m181  20/07/2019  13.05km
# 2     u001     m254    6/8/2020  16.37km
# 3     u001     m116    6/8/2020  16.37km
# 4     u001     m246  16/09/2020  10.82km
# 5     u001     m145   2/10/2020  15.78km
# 6     u001     m230   2/10/2020  15.78km
# 7     u001     m086  10/10/2020  16.84km
# 8     u001     m220  10/10/2020  16.84km
# 9     u001     m015  31/05/2021  11.77km
# 10    u001     m017  31/05/2021  11.77km
# 11    u001     m112    6/7/2021  13.49km
# 12    u001     m070    6/7/2021  13.49km
# 13    u001     m068    6/7/2021  13.49km
# 14    u001     m228  19/07/2021  14.09km
# 15    u001     m134    5/6/2022  17.61km
# 16    u001     m031    5/6/2022  17.61km
# 17    u001     m034    5/6/2022  17.61km
# 18    u001     m163  16/07/2022  15.44km
# 19    u001     m183  16/07/2022  15.44km
# 20    u001     m033  23/07/2022  14.89km
# 21    u001     m048  23/07/2022  14.89km
# 22    u001     m069  19/09/2022  10.29km
# 23    u001     m261  19/09/2022  10.29km
# 24    u001     m005  29/07/2023  17.63km
# 25    u001     m001  29/07/2023  17.63km
# 26    u001     m019   12/7/2024  19.81km
# 27    u001     m280  14/07/2024   9.78km
# 28    u001     m178  14/07/2024   9.78km
# 29    u001     m243  14/07/2024   9.78km
# 30    u001     m279  27/07/2024  12.25km
# 31    u001     m101  26/07/2025  19.85km
# 32    u001     m186  26/07/2025  19.85km
# 33    u001     m090  26/07/2025  19.85km
# 34    u001     m167  26/07/2025  19.85km
# 35    u001     m256  2025-08-30     None
#
#                                               friends  \
# 0                                               Scott
# 1                                       Lou, mum, dad
# 2                                               Scott
# 3                                               Scott
# 4                                               Scott
# 5                                               Scott
# 6                                               Scott
# 7                                          Scott, Lou
# 8                                          Scott, Lou
# 9                                          Scott, Lou
# 10                                         Scott, Lou
# 11                                 Amy F, Jack, Hazel
# 12                                 Amy F, Jack, Hazel
# 13                                 Amy F, Jack, Hazel
# 14                                                Lou
# 15    Scott, Amy F, Jack, Ben, James B, Olivia, Hazel
# 16    Scott, Amy F, Jack, Ben, James B, Olivia, Hazel
# 17    Scott, Amy F, Jack, Ben, James B, Olivia, Hazel
# 18                                       Scott, Darah
# 19                                       Scott, Darah
# 20       Scott, Hazel, Matty, Amy F, Jack, Ben, Eliza
# 21       Scott, Hazel, Matty, Amy F, Jack, Ben, Eliza
# 22                              Scott, Hazel, James B
# 23                              Scott, Hazel, James B
# 24  Scott, Amy F, Jack, Eliza, Hazel, Ben, James B...
# 25  Scott, Amy F, Jack, Eliza, Hazel, Ben, James B...
# 26    Scott, Amy F, Jack, Hazel, James B, Olivia, Ben
# 27                                       Scott, Matty
# 28                                       Scott, Matty
# 29                                       Scott, Matty
# 30                                                Lou
# 31  Scott, Amy F, Jack, Eliza, Matty, Hazel, James...
# 32  Scott, Amy F, Jack, Eliza, Matty, Hazel, James...
# 33  Scott, Amy F, Jack, Eliza, Matty, Hazel, James...
# 34  Scott, Amy F, Jack, Eliza, Matty, Hazel, James...
# 35                                              scott
#
#                                                 notes
# 0   Set out to do 4 but weather was awful. Long wa...
# 1                Louise's 21st birthday! Good weather
# 2                 Pandaaaas. Did the Cobbler as well.
# 3                 Pandaaaas. Did the Cobbler as well.
# 4   Set off at 1pm - probably a mistake. Had to wa...
# 5         Bluebird day in October - took a Friday off
# 6         Bluebird day in October - took a Friday off
# 7   Bit chilly. Had to go back over the first one ...
# 8   Bit chilly. Had to go back over the first one ...
# 9   May bank holiday - another bluebird day. Quite...
# 10  May bank holiday - another bluebird day. Quite...
# 11  Glenshee holiday munros, Team Walk. Started at...
# 12  Glenshee holiday munros, Team Walk. Started at...
# 13  Glenshee holiday munros, Team Walk. Started at...
# 14  For Louise's birthday - too hot! Missed the su...
# 15  Back from America into three meaty munros. Exc...
# 16  Back from America into three meaty munros. Exc...
# 17  Back from America into three meaty munros. Exc...
# 18  With Darah - think she was still friends with ...
# 19  With Darah - think she was still friends with ...
# 20  Invergarry holiday munros - hit a bird with th...
# 21  Invergarry holiday munros - hit a bird with th...
# 22  Statty funes - another one that starts high up...
# 23  Statty funes - another one that starts high up...
# 24  Grantown holiday munros - big stomp but high s...
# 25  Grantown holiday munros - big stomp but high s...
# 26  Braemar holiday munro - all the walks were lon...
# 27  From Glenshee ski centre on the way home from ...
# 28  From Glenshee ski centre on the way home from ...
# 29  From Glenshee ski centre on the way home from ...
# 30  Always choose hot days to do these... swim at ...
# 31  Loch Tay holiday munros - pleasant first half ...
# 32  Loch Tay holiday munros - pleasant first half ...
# 33  Loch Tay holiday munros - pleasant first half ...
# 34  Loch Tay holiday munros - pleasant first half ...
# 35                                              sunny

# %%
cursor.execute("PRAGMA table_info('users');")
columns = cursor.fetchall()

# %%
columns
# Out:
# [(0, 'user_id', 'TEXT', 0, None, 0),
#  (1, 'user_name', 'TEXT', 0, None, 0),
#  (2, 'password', 'INTEGER', 0, None, 0)]

# %%
conn.close()

# %%
bags_df = pd.read_sql_query("SELECT * FROM bags", conn)
bags_df
# Out:
#    user_id munro_id        date distance        friends  \
# 0     u001     m056    9/7/2019     None          Scott
# 1     u001     m181  20/07/2019  13.05km  Lou, mum, dad
# 2     u001     m254    6/8/2020  16.37km          Scott
# 3     u001     m116    6/8/2020  16.37km          Scott
# 4     u001     m246  16/09/2020  10.82km          Scott
# ..     ...      ...         ...      ...            ...
# 84    u000     m280  2024-07-14     None           None
# 85    m005     m220  0008-08-08     None           None
# 86    m009     m040  0088-08-08     None           None
# 87    m009     m169  0099-09-09     None           None
# 88    m009     m276  0088-08-08     None           None
#
#                                                 notes
# 0   Set out to do 4 but weather was awful. Long wa...
# 1                Louise's 21st birthday! Good weather
# 2                 Pandaaaas. Did the Cobbler as well.
# 3                 Pandaaaas. Did the Cobbler as well.
# 4   Set off at 1pm - probably a mistake. Had to wa...
# ..                                                ...
# 84                                               None
# 85                                               None
# 86                                               None
# 87                                               None
# 88                                               None
#
# [89 rows x 6 columns]

# %%
#data.drop(columns="munro_id")

# %%
cursor.execute("""
    SELECT latitude, longitude
    FROM munros
    WHERE munro_id = 'm226'
""")

coords = cursor.fetchone()

# %%
coords
# Out:
# (57.204869, -6.211385)
